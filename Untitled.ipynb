# %%
import glob
import cv2
##print glob.glob(r"C:\Users\Administrator\Documents\Github\vehicle-detection\*\*\*.png")  
##C:\Users\Administrator\Documents\Github\vehicle-detection\training-data\vehicles\
##C:/Users/Administrator/Documents/Github/vehicle-detection/*/*/*.png

f = glob.glob('C:/Users/Administrator/Documents/Github/vehicle-detection/training-data/*/*/*.png')
g = 22
print (f)
print (g)
# Out:
# ['C:/Users/Administrator/Documents/Github/vehicle-detection/training-data\\non-vehicles\\Far\\image0000.png', 'C:/Users/Administrator/Documents/Github/vehicle-detection/training-data\\non-vehicles\\Far\\image0001.png', 'C:/Users/Administrator/Documents/Github/vehicle-detection/training-data\\non-vehicles\\Far\\image0002.png', 'C:/Users/Administrator/Documents/Github/vehicle-detection/training-data\\non-vehicles\\Far\\image0003.png', 'C:/Users/Administrator/Documents/Github/vehicle-detection/training-data\\non-vehicles\\Far\\image0004.png', 'C:/Users/Administrator/Documents/Github/vehicle-detection/training-data\\non-vehicles\\Far\\image0005.png', 'C:/Users/Administrator/Documents/Github/vehicle-detection/training-data\\non-vehicles\\Far\\image0006.png', 'C:/Users/Administrator/Documents/Github/vehicle-detection/training-data\\non-vehicles\\Far\\image0007.png', 'C:/Users/Administrator/Documents/Github/vehicle-detection/training-data\\non-vehicles\\Far\\image0008.png', 'C:/Users/Admini
# ...
